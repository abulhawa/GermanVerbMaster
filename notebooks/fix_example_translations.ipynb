# %% [markdown]
# # German Verb Master · Example Migration Notebook
#
# This notebook replaces the previous TypeScript migration script. It fetches candidate rows from the `words` table, detects the language of legacy example sentences, and helps you curate updates before writing them back to PostgreSQL.
#
# 👉 **Recommended workflow**
#
# 1. Install Python dependencies (see below).
# 2. Configure the database connection string (pulls from the `.env` file by default).
# 3. Run the detection cells, review the output, and adjust the resulting DataFrame.
# 4. When satisfied, run the final cell to apply the updates to the database.
#
# > Always keep a fresh duplicate table (e.g. `words_duplicate_21_10_2025`) before applying changes.

# %% [markdown]
# ## 1. Environment setup
#
# Create/activate a Python environment and install the tooling:
#
# ```bash
# pip install pandas sqlalchemy python-dotenv langdetect langid tqdm
# ```
#
# The notebook expects a `DATABASE_URL` environment variable (same format used by Prisma/Drizzle), e.g.:
#
# ```
# postgresql://postgres:postgres@localhost:5432/german_verbs
# ```
#
# Place it in `.env` at the repo root or export it before launching Jupyter.

# %%
# %pip install pandas sqlalchemy python-dotenv langdetect langid tqdm

# %%
# %load_ext autoreload
# %autoreload 2

import json
import math
import os
from dataclasses import dataclass
from typing import Any, Dict, List, Optional

import langid
import pandas as pd
from dotenv import load_dotenv
from langdetect import DetectorFactory, detect_langs
from sqlalchemy import create_engine, text
from sqlalchemy.engine import Engine
from tqdm.auto import tqdm

DetectorFactory.seed = 42
langid.set_languages(['de', 'en'])

load_dotenv()

DATABASE_URL = os.getenv("DATABASE_URL")
if not DATABASE_URL:
    raise RuntimeError("DATABASE_URL is not set. Update your .env or export it before running this notebook.")

engine: Engine = create_engine(DATABASE_URL)
print("Connected to", engine.url.render_as_string(hide_password=True))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Connected to postgresql://postgres:***@db.kagsgjzijfgvtvkylczl.supabase.co:5432/postgres

# %%
QUERY = text(
    """
    SELECT id,
           lemma,
           pos,
           example_en,
           examples::text AS examples_json
    FROM words
    WHERE example_en IS NOT NULL
      AND TRIM(example_en) <> ''
    ORDER BY id
    """
)

df = pd.read_sql_query(QUERY, engine)
print(f"Loaded {len(df)} candidate rows with legacy example_en content.")
df.head()
# Out:
# Loaded 3080 candidate rows with legacy example_en content.
#    id     lemma pos                     example_en  \
# 0   1  arbeiten   V    Er hat als Koch gearbeitet.
# 1   2     essen   V  Wir haben zu Mittag gegessen.
# 2   3     gehen   V  Wir sind nach Hause gegangen.
# 3   4     haben   V       Er hat viel Geld gehabt.
# 4   5    heißen   V       Sie hat anders geheißen.
#
#                                        examples_json
# 0  [{"sentence": "Sie arbeitete in einer Bank.", ...
# 1  [{"sentence": "Er aß ein Sandwich.", "translat...
# 2  [{"sentence": "Er ging zur Schule.", "translat...
# 3  [{"sentence": "Ich hatte keine Zeit.", "transl...
# 4  [{"sentence": "Er hieß Peter.", "translations"...

# %%
@dataclass
class Detection:
    language: str
    confidence: float
    source: str


def detect_language(text: str) -> Detection:
    cleaned = (text or "").strip()
    if not cleaned:
        return Detection(language="und", confidence=0.0, source="none")

    langid_code, langid_log_prob = langid.classify(cleaned)
    try:
        langid_conf = math.exp(langid_log_prob)
    except OverflowError:
        langid_conf = 0.0

    try:
        candidates = detect_langs(cleaned)
        best = max(candidates, key=lambda entry: entry.prob)
        return Detection(
            language=best.lang,
            confidence=float(best.prob),
            source=f"langdetect:{langid_code}:{langid_conf:.6f}:{langid_log_prob:.3f}",
        )
    except Exception:
        return Detection(language=langid_code, confidence=float(langid_conf), source=f"langid:{langid_log_prob:.3f}")


def parse_examples(raw: Optional[str]) -> List[Dict[str, Any]]:
    if not raw:
        return []
    try:
        parsed = json.loads(raw)
        if isinstance(parsed, list):
            return parsed
    except json.JSONDecodeError:
        pass
    return []


df["examples"] = df["examples_json"].apply(parse_examples)

tqdm.pandas(desc="Detecting languages")
detections = df["example_en"].progress_apply(detect_language)

df["detected_language"] = [d.language for d in detections]
df["language_confidence"] = [d.confidence for d in detections]
df["detection_source"] = [d.source for d in detections]

df.head()
# Out:
# Detecting languages:   0%|          | 0/3080 [00:00<?, ?it/s]
#    id     lemma pos                     example_en  \
# 0   1  arbeiten   V    Er hat als Koch gearbeitet.
# 1   2     essen   V  Wir haben zu Mittag gegessen.
# 2   3     gehen   V  Wir sind nach Hause gegangen.
# 3   4     haben   V       Er hat viel Geld gehabt.
# 4   5    heißen   V       Sie hat anders geheißen.
#
#                                        examples_json  \
# 0  [{"sentence": "Sie arbeitete in einer Bank.", ...
# 1  [{"sentence": "Er aß ein Sandwich.", "translat...
# 2  [{"sentence": "Er ging zur Schule.", "translat...
# 3  [{"sentence": "Ich hatte keine Zeit.", "transl...
# 4  [{"sentence": "Er hieß Peter.", "translations"...
#
#                                             examples detected_language  \
# 0  [{'sentence': 'Sie arbeitete in einer Bank.', ...                de
# 1  [{'sentence': 'Er aß ein Sandwich.', 'translat...                de
# 2  [{'sentence': 'Er ging zur Schule.', 'translat...                de
# 3  [{'sentence': 'Ich hatte keine Zeit.', 'transl...                de
# 4  [{'sentence': 'Er hieß Peter.', 'translations'...                de
#
#    language_confidence        detection_source
# 0             0.999997  langdetect:de:-101.985
# 1             0.999997  langdetect:de:-180.532
# 2             0.999997  langdetect:de:-118.167
# 3             0.999996   langdetect:de:-52.700
# 4             0.999995   langdetect:de:-92.654

# %%
suspected_german = df[(df["detected_language"] == "de") ]
print(f"Potential German example_en sentences: {len(suspected_german)}")
suspected_german[["id", "lemma", "pos", "example_en", "language_confidence", "detection_source"]]
# Out:
# Potential German example_en sentences: 48
#         id           lemma  pos  \
# 0        1        arbeiten    V
# 1        2           essen    V
# 2        3           gehen    V
# 3        4           haben    V
# 4        5          heißen    V
# 5        6           hören    V
# 6        7          kaufen    V
# 7        8          kommen    V
# 8        9          können    V
# 10      11          lernen    V
# 11      12           lesen    V
# 12      13          machen    V
# 13      14          müssen    V
# 14      15        schlafen    V
# 15      16       schreiben    V
# 16      17           sehen    V
# 17      18            sein    V
# 18      19          sollen    V
# 19      20         spielen    V
# 20      21        sprechen    V
# 21      22         trinken    V
# 22      23          werden    V
# 23      24          wohnen    V
# 24      25          wollen    V
# 25      26          fahren    V
# 26      27         fliegen    V
# 27      28          laufen    V
# 28      29       schwimmen    V
# 29      30          tanzen    V
# 30      31     beschließen    V
# 31      32       entstehen    V
# 32      33       erreichen    V
# 33      34       verbinden    V
# 34      35        bewerten    V
# 35      36     durchführen    V
# 36      37      übertragen    V
# 37      38      beinhalten    V
# 38      39     entsprechen    V
# 39      40        erörtern    V
# 40      41  differenzieren    V
# 41      42        gedeihen    V
# 42      43     suggerieren    V
# 140    141          sitzen    V
# 147    148             tun    V
# 894    895            Juni    N
# 925    926           Leute    N
# 1771  1772          Imbiss    N
# 2911  2912           sogar  Adv
#
#                                              example_en  language_confidence  \
# 0                           Er hat als Koch gearbeitet.             0.999997
# 1                         Wir haben zu Mittag gegessen.             0.999997
# 2                         Wir sind nach Hause gegangen.             0.999997
# 3                              Er hat viel Geld gehabt.             0.999996
# 4                              Sie hat anders geheißen.             0.999995
# 5                         Ich habe ein Geräusch gehört.             0.999997
# 6                              Er hat ein Auto gekauft.             0.999998
# 7                       Der Bus ist pünktlich gekommen.             0.999996
# 8                         Das hat er immer gut gekonnt.             0.999995
# 10                                 Er hat viel gelernt.             0.857140
# 11                          Er hat die Zeitung gelesen.             0.999995
# 12                           Sie hat das Essen gemacht.             0.999998
# 13                             Er hat arbeiten gemusst.             0.999997
# 14                             Ich habe gut geschlafen.             0.999998
# 15                     Sie hat eine E-Mail geschrieben.             0.999998
# 16                       Wir haben uns gestern gesehen.             0.999996
# 17                     Sie ist lange in Berlin gewesen.             0.857139
# 18                         Das hätte ich nicht gesollt.             0.999994
# 19                          Wir haben Fußball gespielt.             0.999997
# 20                 Sie hat mit ihrer Mutter gesprochen.             0.999997
# 21                             Er hat Kaffee getrunken.             0.999996
# 22                                Er ist Arzt geworden.             0.999995
# 23                  Sie hat in einem Apartment gewohnt.             0.999997
# 24                           Sie hat das nicht gewollt.             0.999995
# 25                                Er ist Auto gefahren.             0.999999
# 26                       Wir sind nach London geflogen.             0.999996
# 27                     Sie ist einen Marathon gelaufen.             0.999995
# 28                 Sie ist einen Kilometer geschwommen.             0.999997
# 29                             Wir haben Salsa getanzt.             0.999998
# 30           Sie haben eine neue Strategie beschlossen.             0.999997
# 31                Das Problem ist plötzlich entstanden.             0.999997
# 32                          Er hat den Gipfel erreicht.             0.999995
# 33          Sie hat Tradition mit Innovation verbunden.             0.857142
# 34                Die Jury hat die Leistungen bewertet.             0.857141
# 35                  Sie haben eine Studie durchgeführt.             0.999999
# 36           Die Krankheit hat sich schnell übertragen.             0.999996
# 37           Das Angebot hat viele Vorteile beinhaltet.             0.999997
# 38      Die Leistung hat den Anforderungen entsprochen.             0.999998
# 39         Die Experten haben die Problematik erörtert.             0.999996
# 40    Sie hat genau zwischen den Optionen differenzi...             0.999997
# 41                 Die Pflanzen sind prächtig gediehen.             0.999997
# 42        Die Studie hat einen Zusammenhang suggeriert.             0.999996
# 140                                      We were stuck!             0.999994
# 147                                              Do it!             0.714283
# 894                              Summer begins in June.             0.857140
# 925   Note: The work also has masculine zween Theile...             0.999996
# 1771  Der Müller: Edler, gnädiger Fürst,\nSei unsrem...             0.999996
# 2911                       Even Karl can understand it.             0.999995
#
#             detection_source
# 0     langdetect:de:-101.985
# 1     langdetect:de:-180.532
# 2     langdetect:de:-118.167
# 3      langdetect:de:-52.700
# 4      langdetect:de:-92.654
# 5     langdetect:de:-144.378
# 6      langdetect:de:-92.219
# 7     langdetect:de:-126.572
# 8     langdetect:de:-126.957
# 10     langdetect:de:-70.770
# 11    langdetect:de:-151.024
# 12    langdetect:de:-123.235
# 13     langdetect:de:-93.091
# 14     langdetect:de:-86.047
# 15    langdetect:de:-129.483
# 16    langdetect:de:-116.148
# 17     langdetect:de:-55.946
# 18    langdetect:de:-168.690
# 19     langdetect:de:-70.237
# 20    langdetect:de:-132.967
# 21     langdetect:de:-54.607
# 22     langdetect:de:-80.581
# 23    langdetect:de:-120.237
# 24    langdetect:de:-138.870
# 25     langdetect:de:-60.639
# 26    langdetect:de:-106.725
# 27    langdetect:de:-115.614
# 28    langdetect:de:-117.991
# 29     langdetect:de:-46.572
# 30    langdetect:de:-135.717
# 31    langdetect:de:-137.598
# 32    langdetect:de:-106.026
# 33     langdetect:de:-70.312
# 34    langdetect:de:-168.521
# 35    langdetect:de:-153.295
# 36    langdetect:de:-196.799
# 37    langdetect:de:-133.311
# 38    langdetect:de:-241.763
# 39    langdetect:de:-175.448
# 40    langdetect:de:-220.544
# 41    langdetect:de:-188.546
# 42    langdetect:de:-153.323
# 140      langdetect:de:1.947
# 147      langdetect:en:1.648
# 894    langdetect:en:-18.217
# 925   langdetect:de:-558.785
# 1771  langdetect:de:-596.930
# 2911   langdetect:en:-61.089

# %%
detect_langs('Sie hat lange in Paris gelebt.')
# Out:
# [af:0.7142819547522308, de:0.2857165832059127]

# %%
langid.classify('Sie hat lange in Paris gelebt.')
# Out:
# ('de', -89.425368309021)

# %%
langid.classify('Hi, how are you doing today?')
# Out:
# ('en', -38.4182243347168)

# %%
df[["example_en", "detected_language", "language_confidence"]].values.tolist()
# Out:
# [['Er hat als Koch gearbeitet.', 'de', 0.9999969911349207],
#  ['Wir haben zu Mittag gegessen.', 'de', 0.9999971147687953],
#  ['Wir sind nach Hause gegangen.', 'de', 0.9999972605618549],
#  ['Er hat viel Geld gehabt.', 'de', 0.9999955560983653],
#  ['Sie hat anders geheißen.', 'de', 0.9999948145603174],
#  ['Ich habe ein Geräusch gehört.', 'de', 0.9999971686799207],
#  ['Er hat ein Auto gekauft.', 'de', 0.9999975043905702],
#  ['Der Bus ist pünktlich gekommen.', 'de', 0.9999964553791492],
#  ['Das hat er immer gut gekonnt.', 'de', 0.9999952233953684],
#  ['Sie hat lange in Paris gelebt.', 'af', 0.7142819547522308],
#  ['Er hat viel gelernt.', 'de', 0.8571404242961682],
#  ['Er hat die Zeitung gelesen.', 'de', 0.9999954704665728],
#  ['Sie hat das Essen gemacht.', 'de', 0.9999980983059539],
#  ['Er hat arbeiten gemusst.', 'de', 0.9999970253497498],
#  ['Ich habe gut geschlafen.', 'de', 0.9999977429370752],
#  ['Sie hat eine E-Mail geschrieben.', 'de', 0.9999979270940208],
#  ['Wir haben uns gestern gesehen.', 'de', 0.9999962494527482],
#  ['Sie ist lange in Berlin gewesen.', 'de', 0.8571387689643327],
#  ['Das hätte ich nicht gesollt.', 'de', 0.9999944009085908],
#  ['Wir haben Fußball gespielt.', 'de', 0.9999968882895206],
#  ['Sie hat mit ihrer Mutter gesprochen.', 'de', 0.9999966431757231],
#  ['Er hat Kaffee getrunken.', 'de', 0.9999957136365263],
#  ['Er ist Arzt geworden.', 'de', 0.9999949820461189],
#  ['Sie hat in einem Apartment gewohnt.', 'de', 0.9999971180275654],
#  ['Sie hat das nicht gewollt.', 'de', 0.9999945427933643],
#  ['Er ist Auto gefahren.', 'de', 0.9999987546970643],
#  ['Wir sind nach London geflogen.', 'de', 0.9999955651398559],
#  ['Sie ist einen Marathon gelaufen.', 'de', 0.9999951822167157],
#  ['Sie ist einen Kilometer geschwommen.', 'de', 0.9999973056171857],
#  ['Wir haben Salsa getanzt.', 'de', 0.9999976704787564],
#  ['Sie haben eine neue Strategie beschlossen.', 'de', 0.9999969984959248],
#  ['Das Problem ist plötzlich entstanden.', 'de', 0.9999973996737375],
#  ['Er hat den Gipfel erreicht.', 'de', 0.9999952847044299],
#  ['Sie hat Tradition mit Innovation verbunden.', 'de', 0.8571418118620971],
#  ['Die Jury hat die Leistungen bewertet.', 'de', 0.8571407181863311],
#  ['Sie haben eine Studie durchgeführt.', 'de', 0.9999988103975175],
#  ['Die Krankheit hat sich schnell übertragen.', 'de', 0.9999961815984255],
#  ['Das Angebot hat viele Vorteile beinhaltet.', 'de', 0.9999968759668427],
#  ['Die Leistung hat den Anforderungen entsprochen.', 'de', 0.9999979692729476],
#  ['Die Experten haben die Problematik erörtert.', 'de', 0.9999960123550936],
#  ['Sie hat genau zwischen den Optionen differenziert.',
#   'de',
#   0.9999968628563854],
#  ['Die Pflanzen sind prächtig gediehen.', 'de', 0.9999974563368734],
#  ['Die Studie hat einen Zusammenhang suggeriert.', 'de', 0.9999960687524079],
#  ["Her train departs at 5 o'clock.", 'en', 0.8571380227422495],
#  ['to fly over an area (i.e. search and rescue)', 'en', 0.9999978159667939],
#  ['The dictator is not voluntarily relinquishing power despite losing the support of the people.',
#   'en',
#   0.9999965599062031],
#  ["I'll pick you up at the station at eight o'clock.",
#   'en',
#   0.9999963543951176],
#  ['She always offers cookies to her guests.', 'en', 0.9999967343027572],
#  ['The concert is beginning shortly.', 'en', 0.9999976791892012],
#  ['You need to click the icon to start the program.',
#   'en',
#   0.9999975889216057],
#  ['We have arrived at the airport and the flight is delayed.',
#   'en',
#   0.9999978737212031],
#  ['Please tick the correct answer.', 'en', 0.9999967774168197],
#  ['Could you all please turn on your camera?', 'en', 0.9999946681851094],
#  ['Log in and open your inbox to check your emails.',
#   'en',
#   0.9999951927216146],
#  ["I'll call you tomorrow evening.", 'en', 0.9999951898034773],
#  ['The King answered, "If such a man exists, he must be mad."',
#   'en',
#   0.9999961097522582],
#  ['I’m getting dressed.', 'no', 0.9999949996567724],
#  ["The shop has been open since seven o'clock.", 'en', 0.9999968524317883],
#  ['Surely the rain will stop soon.', 'en', 0.9999965565526272],
#  ['He gets up at six every morning.', 'en', 0.9999948868437963],
#  ['The light is off so the children can sleep.', 'en', 0.9999976938317032],
#  ['Please fill out the form completely.', 'en', 0.9999972899234124],
#  ['He is turning off the TV.', 'en', 0.999997194244804],
#  ['You look tired.', 'en', 0.9999976290946255],
#  ['to disembark a bus', 'id', 0.8571396908484963],
#  ['Mr. Müller moved out a week ago.', 'en', 0.9999956731701161],
#  ['In summer we like to swim in the lake.', 'en', 0.5714301151571289],
#  ['A clear sky means a cold night.', 'en', 0.999996724436414],
#  ['The lecture has begun.', 'en', 0.9999970881877093],
#  ["If you stand on your hind legs, you'll get a treat from me.",
#   'en',
#   0.9999970267016401],
#  ['Please use gloves when handling the chemicals.', 'en', 0.9999958429075844],
#  ['The newly discovered camel bones can be visited during Basel Museum Night on the 18th January in the Archaeological Soil Research tent.',
#   'en',
#   0.9999982805224221],
#  ["I'm ordering beer for everyone.", 'da', 0.9999917992073937],
#  ['We visited our mom in the retirement home today.',
#   'en',
#   0.9999968351974438],
#  ['My Uncle Stefan paid for my first car.', 'en', 0.999995486050444],
#  ['We love you. We are sorry. We plead for your pardon. Many thanks.',
#   'en',
#   0.9999974422333986],
#  ['He remained a devoted supporter of the monarchy for all his life.',
#   'en',
#   0.9999965891825348],
#  ['I need your help.', 'en', 0.9999967121011671],
#  ["I'm bringing the cat into the house.", 'en', 0.9999964326255045],
#  ['Could you please spell your name?', 'en', 0.8571399027891001],
#  ['Peter thanked Michaela with a big bouquet.', 'en', 0.9999965687800718],
#  ['The movie lasts two hours.', 'en', 0.9999981793851968],
#  ["I'll print the contract right away.", 'en', 0.9999964541729797],
#  ["Don't press that button!", 'en', 0.9999979167896801],
#  ['I shower every day.', 'en', 0.9999972589434095],
#  ['May I go?', 'tl', 0.714283898679287],
#  ['to go shopping', 'en', 0.857141309889741],
#  ['May I buy you a drink?', 'tr', 0.5714273128394929],
#  ['Please get on quickly; the train is about to leave.',
#   'en',
#   0.9999973354611826],
#  ['In view of their previous work, the specialist merits the promotion.',
#   'en',
#   0.99999390537887],
#  ['The film ends with a surprising scene.', 'en', 0.9999958152558324],
#  ['I can’t excuse what you did.', 'en', 0.9999961165328208],
#  ['The teacher explained the quadratic equation (to me) very well.',
#   'en',
#   0.9999986306899173],
#  ['Eating is not permitted in the library.', 'en', 0.9999986037774561],
#  ['Tell me a fairytale.', 'it', 0.5714291601772802],
#  ['The soup lacks flavor.', 'en', 0.999997174850949],
#  ['In this church, Holy Mass is celebrated every evening.',
#   'en',
#   0.999996338407783],
#  ['In the evening we watch TV for half an hour.', 'en', 0.9999963581555041],
#  ['I found your keys.', 'en', 0.9999957714076222],
#  ['May I ask you something?', 'tl', 0.7142834870388718],
#  ["I'm pleased to meet you. ([It] pleases me to get to know you. (formal))",
#   'en',
#   0.9999970395745659],
#  ['At the weekend we have a long breakfast with the whole family.',
#   'en',
#   0.9999957816912873],
#  ['My wife gave me a new watch.', 'en', 0.9999946577025141],
#  ['I like these trousers.', 'en', 0.9999979643695954],
#  ['The book belongs to me.', 'en', 0.9999956976479332],
#  ['Our team wins the game by two goals.', 'en', 0.9999972302059933],
#  ['Do you believe this story?', 'en', 0.9999960817954157],
#  ['I congratulate you.', 'ro', 0.8571397651055301],
#  ["We're grilling fresh vegetables in the garden this evening.",
#   'en',
#   0.999995170062386],
#  ['to save a penalty kick', 'sk', 0.7142832892878292],
#  ['Who would want to marry such people?', 'en', 0.9999966477854743],
#  ['I helped them with the repair of the car.', 'en', 0.9999974114899863],
#  ['Go get another chair!', 'en', 0.9999975619702183],
#  ['The abolition of this sloppy [pronunciation of Ancient Greek] I will probably never witness, not even should Plato himself rise from the ashes to teach to the German pedagogues the correct pronunciation. They would show him that he was mistaken: that he must have forgotten the correct pronunciation in the more than two millennia following his death, but that they, the German head teachers and principals, knew exactly what it was like: precisely the same as the New High German of the 20th century.',
#   'en',
#   0.9999964292445843],
#  ['On the trip she got to know many new people.', 'en', 0.9999955223632344],
#  ['Nice to meet you! (informal)', 'en', 0.9999983398818826],
#  ['He cooks a soup for the neighbours every Sunday.',
#   'en',
#   0.9999977297860972],
#  ['How much does the ticket to Berlin cost?', 'en', 0.9999955989068475],
#  ['Will you get it ready today?', 'en', 0.857141509033179],
#  ['Who takes care of training the interns?', 'en', 0.9999964774260018],
#  ['to laugh at a joke', 'fi', 0.5714271993098605],
#  ['to lay eggs', 'tl', 0.9999955923409956],
#  ['I love you.', 'sk', 0.7035469070617566],
#  ['In the first three months of the year, the German energy consumption was about two percent below the level of the same period last year.',
#   'en',
#   0.9999975771855399],
#  ["We're renting a small car for the trip.", 'en', 0.9999993998228722],
#  ["I'm bringing my girlfriend (with me).", 'en', 0.9999965735044578],
#  ['He came along (with us).', 'en', 0.9999970838447764],
#  ['I also take part in extracurricular activities.', 'en', 0.9999932305494669],
#  ['She liked him very much.', 'en', 0.9999971351366596],
#  ['Who took my hat?', 'en', 0.9999961262733931],
#  ['The burned-down house is still smoking.', 'en', 0.9999974774472851],
#  ['In April it rains almost every day.', 'en', 0.9999964085806345],
#  ['We want to travel to the Red Sea in summer.', 'en', 0.9999959554365125],
#  ['The technician is repairing the heater today.', 'en', 0.9999966014663579],
#  ['I smell your perfume.', 'fr', 0.5714263351592636],
#  ['They were silent for a long time. When he finally wanted to say something, she softly refused. “Nothing more today, I beg you for that.”',
#   'en',
#   0.9999977248390088],
#  ["All await the light\nBe afraid, don't be afraid\nThe sun is shining out of my eyes\nIt won't set tonight\nAnd the world counts aloud to ten",
#   'en',
#   0.9999959344412267],
#  ['She sent me a love letter.', 'no', 0.714282961513938],
#  ['The store will close at 6 p.m.', 'en', 0.9999980446580591],
#  ['The beer tastes very good.', 'en', 0.9999961627380202],
#  ['We were stuck!', 'de', 0.9999944394076701],
#  ['The house burned down, but the walls are still standing.',
#   'en',
#   0.9999984275010809],
#  ['Put the bottle on the floor!', 'en', 0.9999984591782743],
#  ['She studies chemistry.', 'en', 0.9999974095231375],
#  ['I’m looking for my key.', 'no', 0.8571364148539735],
#  ['She talks on the phone with her sister every evening.',
#   'en',
#   0.9999974449695018],
#  ['See you tomorrow.', 'en', 0.9999964948438302],
#  ['Do it!', 'de', 0.7142828554381978],
#  ['Last month the family moved to a larger apartment.',
#   'en',
#   0.9999975617505443],
#  ['Please sign on the dotted line.', 'en', 0.9999971871553301],
#  ['I make a lot of money at my job.', 'en', 0.9999969669511928],
#  ['I want to sell my car, do you want to buy it?', 'en', 0.9999971073121398],
#  ['In spring she rented out her guest room to students.',
#   'en',
#   0.9999966169016291],
#  ["I can't understand you with this noise.", 'en', 0.9999977009554384],
#  ['And because he had no reason to conceal his name from her, he introduced himself in all due form.',
#   'en',
#   0.9999952744221768],
#  ['I was hiking in the woods when I saw the deer.', 'en', 0.999995091869608],
#  ['We waited for two hours in the cold in front of the stadium.',
#   'en',
#   0.9999985098157858],
#  ['Wash your hands before you sit down to eat.', 'en', 0.9999973156392968],
#  ['When we arrive, the cake will probably already be gone.',
#   'en',
#   0.9999986976381274],
#  ['During practice my back suddenly hurt.', 'en', 0.9999974680044597],
#  ['I hurt you.', 'sw', 0.8571383569580426],
#  ['Could you please fetch the package again?', 'en', 0.9999957378603209],
#  ['Before the exam I reviewed the material once more.',
#   'en',
#   0.9999959122669073],
#  ['I know where you are.', 'en', 0.9999948205532803],
#  ['I have to pay my taxes.', 'en', 0.9999964884383769],
#  ['The pharmacy is probably closed at this hour.', 'en', 0.9999987630893925],
#  ['The child opened the windows.', 'en', 0.9999977052694815],
#  ['Mum? May I sleep over at Sarah’s tonight?', 'en', 0.8571405514249526],
#  ['You have to transfer the amount immediately.', 'en', 0.9999954698190301],
#  ['In the evening I locked the front door twice.', 'en', 0.9999955949496369],
#  ['Have a look at this huge tomato.', 'en', 0.9999960191364734],
#  ['Open [the door] for me.', 'en', 0.8571417435138948],
#  ['Watch out!', 'en', 0.9999957119163605],
#  ['The comment upset him a lot yesterday.', 'en', 0.9999946424285452],
#  ['After the party we tidied up the whole apartment.',
#   'en',
#   0.9999970033162333],
#  ["He wouldn't spend the money on it.", 'en', 0.999995776971168],
#  ['I am not going to the nightclub because I want to dance, but because I want to go out.',
#   'en',
#   0.9999985052219502],
#  ['After the trip she unpacked her suitcase right away.',
#   'en',
#   0.9999973800869866],
#  ["to rest on one's laurels", 'en', 0.5714277435007613],
#  ['Southern Germans [incl. Austrians, Swiss, etc.] pronounce the letters b, d, g without voice.',
#   'en',
#   0.9999973176880637],
#  ['During the break we exchanged experiences about the project.',
#   'en',
#   0.9999964604383726],
#  ['to do a round and distribute e.g. letters, the newspaper, bakery, milk, etc., especially on a regular basis',
#   'en',
#   0.9999987976929345],
#  ['The baker bakes 30 loaves of bread every morning.',
#   'en',
#   0.9999968897043962],
#  ['For the birthday he crafted a colorful card yesterday.',
#   'en',
#   0.99999736330543],
#  ['to build a house', 'en', 0.9999969997193583],
#  ['Yesterday I finally answered all the important emails.',
#   'en',
#   0.9999974237317214],
#  ['You have to thank her. / You have to say thanks to her.',
#   'en',
#   0.9999973101508505],
#  ['She hastened to add that ...', 'en', 0.9999965994941222],
#  ["The announcement put an end to speculation about the company's future.",
#   'en',
#   0.9999973198895473],
#  ['The chairman justified the verdict by stating that an intent to insult was not necessary to constitute the offense.',
#   'en',
#   0.9999960043369606],
#  ['The expert advised us for hours about the options.',
#   'en',
#   0.9999944489819166],
#  ['The newspapers reported the whole story to the world yesterday.',
#   'en',
#   0.9999970438251448],
#  ['In the report she described the accident very precisely.',
#   'en',
#   0.9999971631888245],
#  ['The guest complained about the noise yesterday.', 'en', 0.9999973704672244],
#  ['He has passed the exam.', 'en', 0.9999974668468286],
#  ['And Hanno understood. For it was all only a confirmation of what he had always known.',
#   'en',
#   0.9999979891054495],
#  ['After having received her university degree, she immediately applied to a big car company for a job as an engineer.',
#   'en',
#   0.9999980464701776],
#  ['For dinner he fried the fresh vegetables in the pan.',
#   'en',
#   0.999997854186002],
#  ['At the travel agency I booked the flights last week.',
#   'en',
#   0.999997438798897],
#  ['Yesterday we chatted with our friends until late.',
#   'en',
#   0.9999968433997527],
#  ['I think, therefore I am.', 'en', 0.9999978046942796],
#  ['We need to discuss this issue.', 'en', 0.999995604329134],
#  ['Bettina, wrap your breasts up.', 'en', 0.999997387757601],
#  ['Yesterday I entered the appointment into the calendar.',
#   'en',
#   0.9999965732542028],
#  ['The paint soaked into the paper.', 'en', 0.9999978719560432],
#  ['Last night I suddenly remembered the name.', 'en', 0.9999976265616275],
#  ['The programme fell from her hand.', 'en', 0.9999941737622727],
#  ['At the weekend I photographed the sunrises in the mountains.',
#   'en',
#   0.9999955496960262],
#  ['I feel the sunshine on my face.', 'en', 0.9999967046911008],
#  ['2021 March 10, Jack McGovan, Could rubber from dandelions make tires more sustainable?, in Deutsche Welle (article), retrieved 1 July 2022:\nBoth Continental and competitor Apollo Tyres have used dandelion rubber to manufacture bike tires, […].',
#   'en',
#   0.9999971298073834],
#  ['In the morning I downloaded all the documents from the platform.',
#   'en',
#   0.999997078167663],
#  ['I hope for a complete cure.', 'ro', 0.9999964321292333],
#  ['During the meeting he coughed loudly several times.',
#   'en',
#   0.9999965787503224],
#  ['The apple hangs on the tree.', 'en', 0.9999960100054216],
#  ['He informed us about the upcoming storm.', 'en', 0.9999961659942741],
#  ['Theatre does not interest me.', 'en', 0.9999952272359697],
#  ['Yesterday I jogged for 30 minutes.', 'no', 0.9963312868120678],
#  ['In order to be transportable, this deckchair needs to be folded.',
#   'en',
#   0.9999963569267198],
#  ['He controls the toy truck with that device.', 'en', 0.9999975702863572],
#  ['Last week she resigned from her job at the office.',
#   'en',
#   0.999998297665375],
#  ['abandon all hope', 'en', 0.9999959924757094],
#  ['I’m sorry.', 'en', 0.8561489576584849],
#  ['In the opinion of many economists there should also exist a prohibition for the so-called short sales. In these banks sell shares or currencies that they do not own at all yet or have borrowed at best.',
#   'en',
#   0.9999969740719408],
#  ['More importantly, the goods are delivered in a specified time and place.',
#   'en',
#   0.9999966410519252],
#  ['How old are you? — Er... don’t let me tell you something wrong... Thirty-two.',
#   'en',
#   0.9999950593268597],
#  ['At the weekend he painted a large landscape picture.',
#   'en',
#   0.9999972842919879],
#  ['I think it was last year or the year before.', 'en', 0.9999966084531866],
#  ['You barely notice it.', 'en', 0.99999664197122],
#  ['Are you calling me an idiot?', 'en', 0.8571410827518178],
#  ['Too high a dollar exchange rate ensures high inflation around the world, for raw materials and other goods are traded in dollars.',
#   'en',
#   0.999996623965408],
#  ['In spring the team organized a big conference.', 'en', 0.9999970819606054],
#  ['You need to pack your stuff.', 'en', 0.9999979125801426],
#  ['Yesterday I parked the car behind the house.', 'en', 0.9999972340919526],
#  ['The dress fit her perfectly back then.', 'en', 0.9999959833577365],
#  ['How could that have happened?', 'en', 0.99999957823596],
#  ['We planned the trip back in the last winter.', 'en', 0.9999966908670581],
#  ['At the market she tasted many regional cheeses.', 'en', 0.9999965971914898],
#  ['The technician checked all the cables yesterday.',
#   'en',
#   0.9999958844970903],
#  ['On Saturday I cleaned the windows thoroughly.', 'en', 0.9999956731911368],
#  ['to advise someone to do something', 'en', 0.8571385137792613],
#  ["Here's something fans never thought they'd see.", 'en', 0.9999975406900372],
#  ['The President will talk about the economy in his address.',
#   'en',
#   0.999998279836741],
#  ['Let me ride your tear over your chin to Africa', 'en', 0.9999952643973397],
#  ['In spring we renovated the old living room.', 'en', 0.9999947299190355],
#  ['For the evening I reserved a table in good time.',
#   'en',
#   0.9999972727457049],
#  ['to cry for help', 'en', 0.999997092166278],
#  ['On the walk the children collected colorful leaves.',
#   'en',
#   0.9999960074618599],
#  ['This can only be solved if the teacher constantly releases himself from -- or lifts himself out of -- what is unadventurous, pedantic, narrow-minded.',
#   'en',
#   0.9999973758329203],
#  ['I’m giving my daughter a kitten for her birthday.',
#   'en',
#   0.8571403576348314],
#  ['He is clueless in that field - and someone like that calls himself an expert!',
#   'en',
#   0.9999964734519579],
#  ['The knife won’t cut anymore.', 'en', 0.9999966489324068],
#  ['The autumn leaves fell like snow upon the forest floor.',
#   'en',
#   0.9999978312121289],
#  ['to retire', 'it', 0.999996337571806],
#  ['He walked fast and firmly, trilled to himself, finally he even started to sing in a beautiful dark voice, which seemed unfamiliar to himself.',
#   'en',
#   0.9999985878952117],
#  ["I'm saving my money for a new car.", 'en', 0.9999959584441032],
#  ['Yesterday I took a long walk by the river.', 'en', 0.9999974796460384],
#  ['The competition takes place on Wednesday.', 'en', 0.9999968283960305],
#  ['My dog has died.', 'cy', 0.7142844486764239],
#  ['Yesterday the siblings argued loudly about the game.',
#   'en',
#   0.9999969435743538],
#  ['It bothers me that …', 'en', 0.9999983532094515],
#  ['On vacation we surfed the waves every morning.', 'en', 0.9999974965560081],
#  ['He exchanged the paper clip for a pen.', 'en', 0.9999962674469154],
#  ['In the seminar we divided the tasks fairly.', 'en', 0.9999976288485719],
#  ['Last week she took part in a workshop.', 'en', 0.9999966096265547],
#  ["They couldn't carry the box any longer and had to put it down.",
#   'en',
#   0.9999991403599564],
#  ["I'm training for a marathon.", 'en', 0.9999962633759178],
#  ['The Magic Mountain', 'en', 0.9999965994578366],
#  ['It is planned that passengers who fly from the United States to Europe and change planes there are not checked in the transit area anymore after April 1.',
#   'en',
#   0.9999981142607287],
#  ['He conversed with an employee about the work', 'en', 0.9999977714017789],
#  ['At the weekend we undertook a spontaneous trip.', 'en', 0.7142846033955436],
#  ['2021 March 10, Jack McGovan, Could rubber from dandelions make tires more sustainable?, in Deutsche Welle (article), retrieved 1 July 2022:\nThey scoured the vast and various territories of the Soviet Union and examined over 1,000 different species looking for an alternative to the South American rubber tree, Hevea brasiliensi.',
#   'en',
#   0.9999948417378822],
#  ['After the talk we arranged to meet on Friday.', 'en', 0.9999975044987166],
#  ['I forbid you to talk in that tone of voice with my wife.',
#   'en',
#   0.9999981795475974],
#  ['Yesterday the parties agreed on a compromise.', 'en', 0.9999984124589627],
#  ["I'd completely forgotten all these stories.", 'en', 0.999996500957907],
#  ['The media are comparing the situation to the Cold War.',
#   'en',
#   0.9999957017001622],
#  ['He had a tumble and hurt himself.', 'en', 0.9999945348196104],
#  ['We fell in love.', 'en', 0.9999961259737586],
#  ['I lost my passport again. Do you know where it is?',
#   'en',
#   0.9999974529922104],
#  ['miss the train', 'en', 0.9999943064880266],
#  ['In summer they traveled for several weeks to Spain.',
#   'en',
#   0.9999970485848607],
#  ['Because of the storm we postponed the meeting to Monday.',
#   'en',
#   0.9999981944213341],
#  ["Please be quiet, I'm trying to sleep.", 'en', 0.999994839239166],
#  ['For the exam he prepared every lesson carefully.',
#   'en',
#   0.9999973547194513],
#  ['In spring she swapped the winter tires for summer tires.',
#   'en',
#   0.9999968221253004],
#  ['My cat crawled into my bed and woke me up.', 'en', 0.9999981640844473],
#  ['After the movie she cried softly in the cinema.', 'en', 0.9999973071515699],
#  ["I'm choosing these pants here, the ones with the crease.",
#   'en',
#   0.9999958887689372],
#  ['I want a guinea pig.', 'tl', 0.7142834775712411],
#  ['In art class she sketched a portrait of her friend yesterday.',
#   'en',
#   0.9999973787624576],
#  ['You don’t point your finger at people!', 'fr', 0.8571414336613766],
#  ['Therefore it is necessary to draw the right lessons from the crisis, to learn from the mistakes of the past for securing the future.',
#   'en',
#   0.9999982111226685],
#  ['Listen to me.', 'nl', 0.714280956740306],
#  ['In the evening the shop assistant closed the store on time.',
#   'en',
#   0.9999969408086771],
#  ['After the concert we drove back late at night.', 'en', 0.9999969405518127],
#  ['The customer returned the defective goods immediately.',
#   'en',
#   0.9999986634735715],
#  ['After shopping I went straight back home.', 'en', 0.999994235573956],
#  ['After practice she came back home tired.', 'en', 0.9999961364337904],
#  ['to rewind/run back a tape', 'en', 0.9999983466070741],
#  ["I used to think Botany was boring, but I've changed my opinion.",
#   'en',
#   0.9999971611486249],
#  ['The other kids keep annoying him.', 'en', 0.9999959006465464],
#  ['My daughter is practicing piano.', 'en', 0.9999971946476892],
#  ['We crossed the river.', 'en', 0.9999961692126716],
#  ['I think we took a wrong turn.', 'en', 0.9999992288135396],
#  ['I must withdraw money.', 'en', 0.999996402586642],
#  ['It depends on the weather.', 'en', 0.9999966923002637],
#  ['The offer was turned down.', 'en', 0.9999958258331824],
#  ['Agreed!', 'af', 0.7142829721342714],
#  ['to take off the lid from a pot', 'en', 0.999996956788014],
#  ['In spring she subscribed to the new newsletter.', 'en', 0.9999970181363149],
#  ['Because of the high costs, the company canceled its participation in the project.',
#   'en',
#   0.9999971860736061],
#  ['The monk transcribed the decaying work character by character.',
#   'en',
#   0.9999957901832816],
#  ['We have to coordinate (on this).', 'en', 0.9999972491877488],
#  ['After the meal he washed the dishes thoroughly.', 'en', 0.9999984293810813],
#  ["I'm trying to watch my weight.", 'en', 0.9999976288360328],
#  ['to accept an apology', 'en', 0.9999953417617959],
#  ['Are you having fun?', 'en', 0.5714263064738279],
#  ['In the lab we analyzed the samples yesterday.', 'en', 0.9999965283926083],
#  ["Even though you aren't very knowledgeable about the subject, we must acknowledge your effort.",
#   'en',
#   0.9999974085242322],
#  ['Please state your full name.', 'en', 0.9999958456972686],
#  ['He doesn’t have sandals on.', 'en', 0.7142809168433452],
#  ['It was announced that the train would be a couple minutes late.',
#   'en',
#   0.9999981825486203],
#  ['My mistake. I assumed she was single.', 'en', 0.9999951347922165],
#  ['Last month the family acquired a dog.', 'en', 0.999998555082433],
#  ['The camera can be directly connected to a monitor.',
#   'en',
#   0.9999982048071661],
#  ['Before departure all passengers buckled up.', 'no', 0.4285715452131361],
#  ['The painting appealed to the King.', 'en', 0.9999969167037422],
#  ['He lined up in front of the checkout.', 'en', 0.999997482374599],
#  ["They've really worked hard and made it in time.", 'en', 0.9999959460051553],
#  ['In the project we applied the new method successfully.',
#   'en',
#   0.9999977551676753],
#  ['The neighbours reported the noise to the police.',
#   'en',
#   0.9999969166988897],
#  ['After the run she breathed deeply.', 'en', 0.9999982505927871],
#  ["Don't worry, the pimple isn't noticeable.", 'en', 0.9999979754425528],
#  ['The moderator invited the guests to ask questions.',
#   'en',
#   0.9999968348695876],
#  ['IMDB has listed this film as one of the worst films of all times.',
#   'en',
#   0.9999966905727447],
#  ['He gave up on solving the difficult task.', 'en', 0.9999959513139447],
#  ['The traffic held us up for a long time yesterday.',
#   'en',
#   0.9999978982416405],
#  ['He picked his hat back up, which had been blown off his head.',
#   'en',
#   0.9999970245776973],
#  ['Before the trip I fully charged my phone.', 'en', 0.9999959633705979],
#  ['The company dissolved the contract in autumn.', 'en', 0.9999972446750469],
#  ['When you pick up the bag, make sure to support the bottom.',
#   'en',
#   0.99999768462581],
#  ["I'm writing something down.", 'en', 0.9999962748222584],
#  ['This issue may occur if cookies are disabled in the browser.',
#   'en',
#   0.9999975701352499],
#  ['This morning I woke up with a hangover.', 'en', 0.9999966766722452],
#  ['The school trained many specialists.', 'en', 0.9999956230190161],
#  ['Before the meeting I printed out all the documents.',
#   'en',
#   0.9999983475391523],
#  ['something turns out good, bad, satisfactory', 'en', 0.9999942676068575],
#  ['The supplies barely sufficed in winter.', 'en', 0.9999981936882008],
#  ["No, Mr Müller isn't here. Would you like me to pass on a message?",
#   'en',
#   0.9999973016971099],
#  ['to keep something from the public', 'en', 0.9999973408832448],
#  ['Last year the museum exhibited rare photos.', 'en', 0.9999988846785688],
#  ['Did you pick out a dress for the party?', 'en', 0.9999983369101367],
#  ['From the list she selected three projects.', 'en', 0.9999966307744814],
#  ['Before submitting the application he observed all the notes.',
#   'en',
#   0.9999975967225514],
#  ['At the town hall she applied for a new ID card.', 'en', 0.9999966660853055],
#  ['You must follow suit and play trump.', 'en', 0.9999964949209137],
#  ['The discussion strongly influenced his decision.',
#   'en',
#   0.9999965812241476],
#  ['The safe is situated behind the picture in the living room.',
#   'en',
#   0.9999972915536844],
#  ['I encountered/met the teacher during the break.', 'en', 0.9999969282679493],
#  ['Yesterday I accompanied my grandmother to the doctor.',
#   'en',
#   0.9999967192156974],
#  ['We welcome you to our website.', 'en', 0.9999979680299823],
#  ["I'm keeping it secret.", 'en', 0.428569322914513],
#  ['The physician treated me.', 'en', 0.9999981364224462],
#  ['In the debate he claimed to be right.', 'en', 0.99999575746695],
#  ['mentally challenged', 'en', 0.9999955768491776],
#  ['Red and pink clash.', 'en', 0.999998150200202],
#  ['The school will announce the winners tomorrow.', 'en', 0.9999976415505656],
#  ['In the morning the director announced the results.',
#   'en',
#   0.9999985414072408],
#  ['With his words he insulted many listeners.', 'en', 0.9999971387895297],
#  ['Did you notice the sign we just passed?', 'en', 0.9999971876548703],
#  ["I can't promise anything, but I'll make an effort.",
#   'en',
#   0.9999976578437435],
#  ['For the project we required additional funds.', 'en', 0.9999973499229569],
#  ['You are being watched.', 'en', 0.9999960779830533],
#  ['The engineer calculated the costs very precisely.',
#   'en',
#   0.9999993343688711],
#  ["to soothe (sb's) anger.", 'en', 0.9999950904521053],
#  ['We should keep any unnecessary conversation to a minimum.',
#   'en',
#   0.9999981313100538],
#  ['The storm damaged several roofs during the night.',
#   'en',
#   0.9999947157982474],
#  ['I kept myself busy with the Wiki today.', 'en', 0.9999986056504835],
#  ['The group occupied the front rows early.', 'en', 0.9999981430632325],
#  ['His operations have been managed by a proxy.', 'en', 0.999996606769245],
#  ['In the afternoon we discussed the new contract.', 'en', 0.9999985154265816],
#  ['The judge punished the offender with a fine.', 'en', 0.9999977135498233],
#  ['Many citizens took part in the discussion about the park.',
#   'en',
#   0.9999983479417256],
#  ["Young musicians apply, some of them by video. Around 70 of them are selected to rehearse for several weeks parallel to the Salzburg Festival, supervised by members of Vienna's leading orchestra.",
#   'en',
#   0.99999426095412],
#  ['She deceives you with her disingenuous care for you.',
#   'en',
#   0.9999962368231701],
#  ['to undeniably prove (sth).', 'en', 0.9999960635657312],
#  ['At the concert the band offered a great program.',
#   'en',
#   0.9999975036117601],
#  ['During the thunderstorm it flashed continuously.',
#   'en',
#   0.9999974435195459],
#  ['After the fall his knee bled badly.', 'en', 0.9999972401262839],
#  ['In spring the fruit trees bloomed especially beautifully.',
#   'en',
#   0.9999970796775606],
#  ['The wind broke several branches off during the night.',
#   'en',
#   0.9999954468688748],
#  ['Before the traffic light the driver braked in time.',
#   'en',
#   0.9999976255813038],
#  ['I watched the house burn.', 'en', 0.9999974303264292],
#  ['In his presentation he illustrated the results vividly.',
#   'en',
#   0.9999962747379365],
#  ['For the celebration we decorated the hall with lights.',
#   'en',
#   0.9999974281928625],
#  ['This church served as a hospital during the invasion.',
#   'en',
#   0.9999970009137211],
#  ['At night it thundered heavily over the city.', 'en', 0.9999995378862505],
#  ['Turn the mirror a little to the left!', 'en', 0.9999986534140847],
#  ["The fact that Dutch people often come across as relaxed and informal to German people also has to do with the fact that Dutchmen are very quick to use the informal form of address, especially at unexpected moments. Unlike in Germany, however, the Dutch informal you does not imply any particular familiarity; it's more comparable to the English you. In business dealings, it is customary to start addressing each other with the informal you without any prior notice, in the middle of a conversation. (...) Being on first-name terms does not signal that people have become closer in any way, that they find the other person likeable, or that they'll negotiate any less toughly. Especially between Germans and Dutch there often arise misunderstandings in this respect. If, for example, a manager allows himself to be addressed using the informal you, Germans tend to interpret this as a sign of a particularly good work environment, whereas the informal you is simply a conventional way of addressing people.",
#   'en',
#   0.9999968389205081],
#  ['Because of my weak muscles, I am not suitable as a construction worker.',
#   'en',
#   0.9999974430892293],
#  ['I hurried to the railway station.', 'en', 0.9999981788487151],
#  ['Someone broke into the apartment.', 'en', 0.9999977391966826],
#  ['Think of something!', 'en', 0.9999969516872558],
#  ['In the text I inserted the corrected figures.', 'en', 0.9999975198690066],
#  ['Marco Polo is said to have introduced pasta to the Western world.',
#   'en',
#   0.9999992120006456],
#  ['After difficult talks, we agreed to the following.',
#   'en',
#   0.9999975650395667],
#  ['to take first place', 'en', 0.9999942974719651],
#  ['The grandchildren had furnished their own rooms according to their personal taste.',
#   'en',
#   0.9999963301011797],
#  ['German and Dutch state railroads wanted to carve up a market worth billions between themselves. Now the federal antitrust agency has intervened.',
#   'en',
#   0.9999948570361791],
#  ['We should appoint him (as) head of the commission.',
#   'en',
#   0.9999979141184643],
#  ['I have to set up the device first before I can work with it.',
#   'en',
#   0.9999961423860353],
#  ['Please enter!', 'es', 0.8571390676895091],
#  ['At the counter he paid the money into the account.',
#   'en',
#   0.9999974532739342],
#  ['The hosts warmly received the guests at the door.',
#   'en',
#   0.9999991283414529],
#  ['We spotted a bear in the forest.', 'en', 0.9999968449715745],
#  ['The caretaker is removing the graffiti from the wall.',
#   'en',
#   0.9999965322793947],
#  ['to meet each other half way', 'en', 0.9999953544480402],
#  ['These dishes contain little fat.', 'en', 0.9999961880915412],
#  ['He was released from prison.', 'en', 0.9999978395899123],
#  ['I have decided to quit smoking starting next week.',
#   'en',
#   0.8571380912903218],
#  ['After much hesitation she decided to pursue a degree.',
#   'en',
#   0.9999972141066424],
#  ['After the renovation we disposed of the old carpet.',
#   'en',
#   0.9999986549444024],
#  ['The archer relaxed the bow again and put the arrow back in the quiver.',
#   'en',
#   0.9999977797185953],
#  ['His behavior badly disappointed the team.', 'en', 0.9999958551898096],
#  ['Have you finally developed a sense of humor?', 'en', 0.9999969723714697],
#  ['It happened as follows.', 'en', 0.9999980165578182],
#  ["I learned about Helga's death from the newspaper.",
#   'en',
#   0.9999963759186704],
#  ['Years ago she invented a practical kitchen device.',
#   'en',
#   0.9999959762612798],
#  ['The project required a lot of patience and perseverance.',
#   'en',
#   0.9999974231486376],
#  ['The bowl was entirely filled by a mysterious liquid.',
#   'en',
#   0.999995678428415],
#  ['In the form I added the missing information.', 'en', 0.9999959101106811],
#  ['I received this coffeemaker as a gift.', 'en', 0.9999962323781062],
#  ['After the operation he recovered remarkably quickly.',
#   'en',
#   0.9999971697973054],
#  ['to heighten our morality', 'en', 0.9999954421327126],
#  ["I didn't recognize you in that hat.", 'en', 0.9999967248144322],
#  ['At the counter she inquired about the next connection.',
#   'en',
#   0.9999970214922616],
#  ['In winter I caught a cold after a short walk.', 'en', 0.9999972204152472],
#  ['We are experiencing some turbulence right now.', 'en', 0.9999970083529713],
#  ['When my master got up / he sent his body gunner / to get me out of the goose pen. / He brought the news / that he had found the door open / and a hole cut with a knife behind the bolt, / with the help of which the prisoner would have freed himself.',
#   'en',
#   0.9999946415497643],
#  ['The new software made the work much easier for us yesterday.',
#   'en',
#   0.9999974761498628],
#  ['They eat jellyfish, squids and plankton.', 'en', 0.9999936427526213],
#  ['I got scared.', 'en', 0.8571407764875658],
#  ["I'm replacing my old car with a new one.", 'en', 0.9999975137686095],
#  ['It is important that you create an account.', 'en', 0.9999959220045367],
#  ["Don't worry, I'm expecting help to arrive soon.", 'en', 0.9999975820837725],
#  ['The prison, which today in Germany is not supposed to punish anymore but to better and educate, has thereby advanced to the military hospital of the bourgeois order, so to speak.',
#   'en',
#   0.999997771839667],
#  ['The new gallery opens on Monday.', 'en', 0.9999966727841857],
#  ['The goalkeeper catches the ball.', 'en', 0.9999965049882547],
#  ['One of them had this spring bordered and led into the well so that the good arable people could quench their thirst and water their cattle.',
#   'en',
#   0.9999970526772765],
#  ['On the beach we lazed around all day.', 'en', 0.9999983453064227],
#  ["to hold on to (it) with all one's strength.", 'en', 0.999996191956679],
#  ['The law determines among other things that the government can wind up a bank in an orderly fashion in case of its impending bankruptcy.',
#   'en',
#   0.9999959351188515],
#  ['The police arrested the suspect yesterday.', 'en', 0.9999952874833122],
#  ['The authority set the new fee yesterday.', 'en', 0.9999961834115554],
#  ['After the conversation the result was finally certain.',
#   'en',
#   0.9999979617293495],
#  ['I will now determine how well the device works.', 'en', 0.9999973300661764],
#  ['The foundation financed the project completely last year.',
#   'en',
#   0.999995526718211],
#  ['When the police arrived, the robber had already fled.',
#   'en',
#   0.9999974393025157],
#  ['After the storm the brook flowed calmly through the valley again.',
#   'en',
#   0.9999955127044078],
#  ['The hero followed the dragon to its cave.', 'en', 0.9999957875877259],
#  ['The most difficult decisions require the strongest wills.',
#   'en',
#   0.9999964895609637],
#  ['He is continuing his studies in Berlin.', 'en', 0.8571397683823166],
#  ['First comes the stomach, then comes ethics.', 'en', 0.9999975130116681],
#  ['Are you cold?', 'fr', 0.7142824558600483],
#  ['The new washing machine works perfectly.', 'en', 0.9999979527269948],
#  ['The city generously promoted the cultural project.',
#   'en',
#   0.9999980072302236],
#  ["The shop doesn't carry cigarettes.", 'en', 0.9999982056347105],
#  ['Before the exam she was more afraid than usual.', 'en', 0.9999971970049147],
#  ['to feed the birds with sunflower seeds', 'en', 0.9999984326806797],
#  ['The manufacturer guaranteed the quality for five years.',
#   'en',
#   0.9999956836689415],
#  ['In the course we used many technical terms yesterday.',
#   'en',
#   0.9999975287118575],
#  ["Your hours, moments\nlet's see if you turn out well.",
#   'en',
#   0.8571399473198353],
#  ['But the law of democracy is only in force between the citizens and their state. In foreign policy the primacy of the government is traditionally in force.',
#   'en',
#   0.9999975732492767],
#  ['Yesterday the committee approved the construction plan without opposition.',
#   'en',
#   0.9999977171899828],
#  ['to enjoy life', 'es', 0.857139712205768],
#  ['Few rules are enough for a functioning game.', 'en', 0.9999949482430538],
#  ['How could that have happened?', 'en', 0.99999957823596],
#  ['She accustoms her body to the bitter cold.', 'en', 0.9999974738588929],
#  ['The oil is poured into the tanks.', 'en', 0.9999970803939059],
#  ['to touch something', 'en', 0.9999973040777825],
#  ['In the garden we barbecued fresh fish on Sunday.',
#   'en',
#   0.9999980106910991],
#  ['to start a family', 'en', 0.9999972136724578],
#  ['On the way to work he greeted the neighbors kindly.',
#   'en',
#   0.99999727899646],
#  ['I can go into town and sit myself down somewhere and stare into space.',
#   'en',
#   0.9999967852694249],
#  ['In the evening it suddenly hailed in the village.',
#   'en',
#   0.9999969282005747],
#  ['Everybody is responsible for the way they act.', 'en', 0.9999974650865611],
#  ['There is nothing I hate more than wasps.', 'en', 0.9999970650756606],
#  ['At the gym she lifted the weights with steady strength.',
#   'en',
#   0.9999964772312632],
#  ['In winter we heated the old house carefully.', 'en', 0.9999978808723409],
#  ['With much patience we found out the cause of the error.',
#   'en',
#   0.9999984057881235],
#  ['After the meeting I shut down the computer properly.',
#   'en',
#   0.9999970439759855],
#  ['The deer left tracks in the snow.', 'en', 0.8571409668790161],
#  ['This is clearly indicated on warning signs at the site.',
#   'en',
#   0.9999986696203096],
#  ['In the evening she uploaded the photos to the cloud.',
#   'en',
#   0.9999972471296348],
#  ['In the traffic jam the driver honked impatiently.',
#   'en',
#   0.9999976220225375],
#  ['Yesterday I installed the new software on the laptop.',
#   'en',
#   0.9999985785008415],
#  ['The teacher quickly integrated the new students into the class.',
#   'en',
#   0.9999963784966871],
#  ["We wandered around the city for an hour because we couldn't find the hotel.",
#   'en',
#   0.9999970865583689],
#  ['Be careful not to break the glass.', 'en', 0.9999980510859283],
#  ['During transport the glass unfortunately broke.', 'en', 0.9999967938383978],
#  ['Buy cars, buy houses, buy furniture, buy trips / for what? / break what breaks you',
#   'en',
#   0.9999970582112256],
#  ['After the decision the association filed a lawsuit in court.',
#   'en',
#   0.9999962788988891],
#  ['The mud was sticking to the shoes.', 'en', 0.9999961922114264],
#  ['On vacation we climbed to the summit early in the morning.',
#   'en',
#   0.999998728759032],
#  ['The thief had absconded at first, but handcuffs clicked shut shortly later.',
#   'en',
#   0.9999970884281808],
#  ['Hastily he answers the questions while the telephone is ringing without intermission.',
#   'en',
#   0.999996146027113],
#  ['All bells sound differently.', 'en', 0.9999964485189592],
#  ['to knock on the door', 'en', 0.9999981589108219],
#  ['You have to sort out that question for youself.', 'en', 0.7142841203171273],
#  ['In the past many teenagers consumed too much sugar.',
#   'en',
#   0.9999970651872043],
#  ['In the next few months I will focus on my new book.',
#   'en',
#   0.9999970503258565],
#  ['For the meeting I photocopied the documents three times.',
#   'en',
#   0.9999975760587563],
#  ['In the evening she corrected the last exams.', 'en', 0.9999952870654643],
#  ['In the review he sharply criticized the film.', 'en', 0.999998312815982],
#  ['Against stupidity, the gods themselves contend in vain.',
#   'en',
#   0.9999964108919228],
#  ['She only kissed him like a sister.', 'en', 0.8571405608801344],
#  ['The plane lands on the runway.', 'en', 0.9999972875135481],
#  ['During the long speech we were extremely bored.', 'en', 0.9999966564258075],
#  ['Learn to suffer without complaining.', 'en', 0.9999975701236977],
#  ['We did a good job.', 'so', 0.714284616447756],
#  ['Two years ago she led the entire project team.', 'en', 0.99999842263254],
#  ['(please add an English translation of this quotation)',
#   'en',
#   0.9999950648994717],
#  ["It's worth it!", 'en', 0.9999983934467178],
#  ["At six o'clock we set off toward the coast.", 'en', 0.999995635922004],
#  ['At the greeting he smiled kindly.', 'en', 0.9999953790189716],
#  ['to quench the thirst', 'en', 0.9999984486667879],
#  ['"to remove (something) from (something else)"', 'en', 0.7182101369597671],
#  ['In the text she highlighted the most important passages in yellow.',
#   'en',
#   0.9999971983528996],
#  ['The principal reported the accident.', 'en', 0.999997121821409],
#  ['Very serious, with one eyebrow lifted, he measured little Hanno with cold and scrutinizing glance.',
#   'en',
#   0.9999984338862964],
#  ['For the cake he carefully mixed butter and sugar.',
#   'en',
#   0.9999980030647525],
#  ['This was announced by the EU President.', 'en', 0.999998354480433],
#  ['I thought about it and decided to buy the car.', 'en', 0.999996700865341],
#  ['In the dictionary I looked up the unfamiliar word.',
#   'en',
#   0.9999969090605498],
#  ['You should make use of your talents.', 'en', 0.9999976034640932],
#  ['In the evening she sewed the buttons back on.', 'en', 0.999998404104903],
#  ['Carefully we approached the shy animal.', 'en', 0.9999956283824522],
#  ['The hint was of little use to us in the situation.',
#   'en',
#   0.9999979003306859],
#  ['The surgeon operated on the patient very precisely.',
#   'en',
#   0.9999965186339566],
#  ['Yesterday I arranged the documents in new folders.',
#   'en',
#   0.9999968545406336],
#  ['In Zurich I parked the car in the underground garage.',
#   'en',
#   0.9999969650357714],
#  ['Last year the company retired three employees.', 'en', 0.999996665289033],
#  ['In spring the children planted young trees in the yard.',
#   'en',
#   0.9999965112466072],
#  ['to nurse someone back to health', 'en', 0.9999953058904659],
#  ['Our company produces office utensils.', 'en', 0.5714280309321981],
#  ['On Saturday many people protested in the square.',
#   'en',
#   0.9999968378276869],
#  ['Yesterday she presented the results to the team.',
#   'en',
#   0.9999980340238162],
#  ['He shaves (himself).', 'en', 0.9999969680694345],
#  ['How will the markets react to the news?', 'en', 0.9999983055629043],
#  ['After long planning we finally realized the concept.',
#   'en',
#   0.9999979536419219],
#  ['With new measures we significantly reduced the energy consumption.',
#   'en',
#   0.9999976357224347],
#  ['In the contract the partners regulated all important details.',
#   'en',
#   0.9999968668992543],
#  ['The tower almost reaches the sky.', 'en', 0.9999981441358319],
#  ['In the morning he cleaned the machines thoroughly.',
#   'en',
#   0.9999985760112104],
#  ['In this class, nobody runs as fast as Mike.', 'en', 0.999996873791861],
#  ['This cat was a stray that was rescued from an animal shelter.',
#   'en',
#   0.99999735525134],
#  ['We must not just throw the trash out of the window.',
#   'en',
#   0.9999981547467092],
#  ["It can't hurt to give it a try.", 'en', 0.9999971306107996],
#  ['At the intersection the traffic light finally switched to green.',
#   'en',
#   0.9999957500101746],
#  ['I like to watch football/soccer.', 'en', 0.9999963381604551],
#  ['The judge refused to dissolve the marriage.', 'en', 0.9999977508608033],
#  ['We pushed the heavy cart slowly up the slope.', 'en', 0.9999964375668514],
#  ['to shoot at something', 'en', 0.9999976123258002],
#  ['I always put on my make-up at home in front of the mirror.',
#   'en',
#   0.9999965885541674],
#  ['Why are you shouting?', 'en', 0.9999971163248028],
#  ['Who is silent agrees!', 'en', 0.9999955899984836],
#  ['In the heat all participants sweated heavily.', 'en', 0.9999974724103903],
#  ['During the meeting he cautiously estimated the costs.',
#   'en',
#   0.9999989042108612],
#  ['Baby brother, come hold on tight / and shake the leaves from my tree',
#   'en',
#   0.9999967354563553],
#  ['Gods protect good people.', 'en', 0.9999967000993812],
#  ['Yesterday I sent the documents by email.', 'en', 0.999997892106556],
#  ['Before the update I backed up all the important data.',
#   'en',
#   0.9999972931709695],
#  ['In the final our team won convincingly.', 'en', 0.999997688295164],
#  ['In the conversation we addressed the new colleagues formally at first.',
#   'en',
#   0.9999982526564322],
#  ['The sun has set.', 'en', 0.999998155287672],
#  ['He takes care of the household.', 'en', 0.9999977241284466],
#  ['Last Sunday we went for a walk on the beach.', 'en', 0.9999976026531208],
#  ['At the championship she jumped over two meters high.',
#   'en',
#   0.9999961253192551],
#  ['Please rinse your bottles before recycling them.',
#   'en',
#   0.9999960066866439],
#  ['Wait! I sense danger.', 'af', 0.5738444046525104],
#  ['The Stranger is originally from Scotland.', 'en', 0.9999980092198578],
#  ['The plane started on time.', 'en', 0.9999958317212976],
#  ['Could you vacuum the hallway, please?', 'en', 0.9999971564741554],
# ...
#  ['Many Europeans like to travel to the seaside in summer.',
#   'en',
#   0.9999968130324206],
#  ['The driver checked the brakes once more before departure.',
#   'en',
#   0.9999967630134461],
#  ['The ticket is also valid for the bus in the city centre.',
#   'en',
#   0.9999960681543998],
#  ['Her bicycle got a new saddle and brighter lights.',
#   'en',
#   0.9999970603152879],
#  ['The family spends every Sunday together in the garden.',
#   'en',
#   0.9999959473706093],
#  ['The family name originally comes from the Black Forest.',
#   'en',
#   0.9999963288102185],
#  ['The questionnaire asks for marital status right at the start.',
#   'en',
#   0.9999967804000758],
#  ['The paint on the living room wall dried slowly.', 'en', 0.9999953366587555],
#  ['The fax only went through after several attempts.',
#   'en',
#   0.9999959743323503],
#  ['In February we traditionally plan our ski vacation.',
#   'en',
#   0.9999975344038385],
#  ['The error in the report was corrected in time.', 'en', 0.9999960312042322],
#  ["Let's call it a night!", 'en', 0.9999945305409386],
#  ['On the public holiday most shops remain closed.', 'en', 0.9999971171425251],
#  ['to catch fire', 'en', 0.9999980955053482],
#  ['The fever dropped noticeably after the second tablet.',
#   'en',
#   0.9999976817220839],
#  ['The film tells the story of a courageous researcher.',
#   'en',
#   0.9999979461514258],
#  ['The company hired ten new employees this year.', 'en', 0.99999644113634],
#  ['Each one of us has caught a fish.', 'en', 0.9999962266472887],
#  ['We’d like a bottle of your chardonnay and a bottle of still water with it.',
#   'en',
#   0.9999970251335633],
#  ['The meat simmered slowly with herbs in the pot.', 'en', 0.9999977225337853],
#  ['The airport was unusually empty in the morning.', 'en', 0.9999960741753242],
#  ['The airplane landed safely on the runway despite the fog.',
#   'en',
#   0.9999986663781522],
#  ['The form had to be filled out completely and legibly.',
#   'en',
#   0.9999969251623736],
#  ['to take a photo.', 'en', 0.5714261319178515],
#  ['A question for you.', 'fr', 0.999996282419008],
#  ['(please add an English translation of this quotation)',
#   'en',
#   0.9999950648994717],
#  ['On Friday after work we meet up at the bistro.', 'en', 0.9999964384467006],
#  ['You can read the newspaper in your free time.', 'en', 0.9999974208515761],
#  ['Let’s stay friends.', 'da', 0.857138828215953],
#  ['In early spring the work in the allotment garden begins.',
#   'en',
#   0.9999979553462534],
#  ['In spring the cherry trees in the park burst into bloom.',
#   'en',
#   0.9999974867581066],
#  ['They usually have their breakfast in bed.', 'en', 0.999996698719224],
#  ['He carefully placed his foot on the bandage.', 'en', 0.9999973922952308],
#  ['On Sunday a thrilling football match is on TV.', 'en', 0.9999971426392822],
#  ['The SED leadership turned a deaf ear.', 'en', 0.9999965156224724],
#  ["We're sitting in the garden.", 'en', 0.9999968203793219],
#  ['Each guest brought a small contribution to the buffet.',
#   'en',
#   0.999995959252812],
#  ['The year of birth is printed on the back of the ID.',
#   'en',
#   0.999998132069577],
#  ['The place of birth is clearly noted on the certificate.',
#   'en',
#   0.9999975357007315],
#  ['She received a stack of handwritten cards for her birthday.',
#   'en',
#   0.999994660011608],
#  ['He put the money for the holiday into a separate account.',
#   'en',
#   0.9999971306992136],
#  ['Eat your vegetables!', 'fr', 0.4285710001755786],
#  ['The luggage was delivered directly to the hotel.',
#   'en',
#   0.9999982578151145],
#  ['The gift was lovingly wrapped in cloth.', 'en', 0.9999948662866551],
#  ['My siblings are visiting us this weekend for a barbecue.',
#   'en',
#   0.9999964096376902],
#  ['At around 100 vendor booths you get associations and businesses presenting themselves and local restaurateurs offer their choice delicacies.',
#   'en',
#   0.9999967716221497],
#  ['to come up in conversation.', 'it', 0.8571412585947348],
#  ['A complimentary drink comes with every main course.',
#   'en',
#   0.9999969842692971],
#  ['With its length of 30 meters and weight of sometimes more than 150 tons the blue whale surpasses every other animal on Earth.',
#   'en',
#   0.9999971950751017],
#  ['A freshly filled glass of champaign was in front of him. He emptied it in one draught – with pleasure, almost with greed.',
#   'en',
#   0.9999956767117174],
#  ['The train to Cologne departs from platform seven today.',
#   'en',
#   0.9999984668389078],
#  ['The greatest joy in life is to be loved.', 'en', 0.9999975075552165],
#  ['She wrote a heartfelt congratulations on passing the exam.',
#   'en',
#   0.9999966044626499],
#  ['Zero degrees Celsius (0°C) are 273.15 Kelvin.', 'nl', 0.9999947645088467],
#  ['Only one gram of salt was missing from the recipe.',
#   'en',
#   0.9999954875527155],
#  ['(please add an English translation of this quotation)',
#   'en',
#   0.9999950648994717],
#  ['My grandmother bakes the best apple strudel.', 'en', 0.9999961027135696],
#  ['The grandfather shows the grandchildren the old photo album.',
#   'en',
#   0.9999979446286382],
#  ['The group divided among the three work rooms.', 'en', 0.9999979399348635],
#  ['He sent me a greeting from vacation.', 'en', 0.999996132032358],
#  ['What size do you wear (or have)?', 'en', 0.999995026581332],
#  ['She has long blonde hair.', 'en', 0.9999950137811757],
#  ['The room includes half board.', 'en', 0.999997571581106],
#  ['The trade fair takes place in the large hall.', 'en', 0.9999962059899111],
#  ['Where is the next bus/tram stop?', 'en', 0.9999968908110914],
#  ['Save me, he mumbled to himself, involuntarily with folded hands, as if it were a prayer to her.',
#   'en',
#   0.9999960962728824],
#  ["Every few minutes he's on his cell phone arranging appointments.",
#   'en',
#   0.9999965350794608],
#  ['The homework assignment was very difficult.', 'en', 0.9999969262411111],
#  ["The homemaker organizes the family's daily routine with plenty of energy.",
#   'en',
#   0.9999969874993342],
#  ['The janitor/caretaker repairs the defective door.',
#   'en',
#   0.9999950312211539],
#  ['I left my native Turkey two years ago.', 'en', 0.9999979487354689],
#  ['The leaves turn brown in autumn.', 'en', 0.9999955040505238],
#  ['The cooker consists of an oven and four rings.', 'en', 0.9999959379571284],
#  ["gentlemen's wear", 'nl', 0.9999929275795194],
#  ['first aid', 'en', 0.9999960784400768],
#  ['My hobby is reading.', 'en', 0.999995295341305],
#  ['The Oscar award winner’s wedding was the main topic of the yellow press for days.',
#   'en',
#   0.9999983416208298],
#  ['We are staying in a hotel in the city.', 'en', 0.9999983162807449],
#  ['A dog barks when he has perceived something with the senses; thereupon, because his barking scares and upsets him, and furthermore, because the perceived object looks after him, does not look after him, or runs away.',
#   'en',
#   0.9999973326775684],
#  ['I am very hungry! (Literally: I have great hunger!)',
#   'no',
#   0.5714274602323599],
#  ['We are ordering a whole chicken.', 'en', 0.9999952639813076],
#  ['We need more information about the case.', 'en', 0.9999982431338945],
#  ['Is the internet fast here?', 'en', 0.9999983276941303],
#  ['Put on your jacket, it is cold.', 'en', 0.9999949433138039],
#  ['year after year', 'en', 0.8571411653899265],
#  ['In January many people start new habits.', 'en', 0.999996970094619],
#  ['If I get the job, I might be able to afford a car.',
#   'en',
#   0.9999967933860701],
#  ['The teenagers independently organized a charity concert.',
#   'en',
#   0.9999962789446567],
#  ['In July we go to the lake with friends.', 'en', 0.999996230120175],
#  ['The boy is playing in the garden.', 'en', 0.9999972536321914],
#  ['Summer begins in June.', 'de', 0.857139520211013],
#  ["On Sunday, we go to Grandma's for coffee [and cake].",
#   'en',
#   0.9999975832894307],
#  ['Can I pay by card?', 'en', 0.9999970401456563],
#  ['I know Germans [lit. potatoes] who, like me, forgo schnapps and other alcoholic beverages voluntarily and without a "compelling reason" for doing so.',
#   'en',
#   0.9999973440952474],
#  ['Because the government does not find a solution for the desperate financial situation in the health care sector, numerous health insurance institutions are threatened by bankruptcy.',
#   'en',
#   0.9999971385132822],
#  ['A kilo of fresh tomatoes is plenty for the soup.',
#   'en',
#   0.9999987381527169],
#  ['I need two kilograms of apples.', 'en', 0.9999955877696644],
#  ['It is ten kilometers to the train station.', 'en', 0.9999968288171661],
#  ['An adult cannot become a child again, or he becomes childish. But does not the naïveté of the child give him pleasure, and must he not himself endeavour to reproduce the child’s veracity on a higher level?',
#   'en',
#   0.9999976181663033],
#  ['My child goes to kindergarten/daycare.', 'en', 0.8571409115953764],
#  ['We are going to the cinema tonight.', 'en', 0.9999984444176491],
#  ['I am buying a newspaper at the kiosk.', 'en', 0.9999977107330894],
#  ['The fear that a reunited Germany would pursue its national interests more strongly in the long term and act unilaterally – hence without consideration of its neighbors – haunts the political class of France since that time.',
#   'en',
#   0.9999977165364151],
#  ['She is wearing beautiful clothing.', 'en', 0.9999973716372168],
#  ['Have you packed your suitcase?', 'en', 0.9999979729283659],
#  ['My colleague is helping me with work.', 'en', 0.9999970354200864],
#  ['My account is almost empty.', 'en', 0.9999977049395004],
#  ['He fell down the stairs when she threw a book at his head.',
#   'en',
#   0.9999949243337753],
#  ['He pays with a credit card.', 'en', 0.9999962518893148],
#  ['Would you like a slice of cake?', 'en', 0.9999956037287724],
#  ['May I have your biro for a second?', 'en', 0.9999968887848392],
#  ['The customer is king.', 'en', 0.9999963742634694],
#  ['The female customer chose the blue dress after much deliberation.',
#   'en',
#   0.9999956244495981],
#  ['change of direction', 'en', 0.9999971883876597],
#  ['The kitchen is very modern.', 'en', 0.9999983486755699],
#  ['Put the milk in the refrigerator.', 'en', 0.9999961574689373],
#  ['When do the shops close around here?', 'en', 0.9999960479655483],
#  ['Which country would you like to visit?', 'en', 0.9999966442430664],
#  ['The art of living.', 'en', 0.9999964597167816],
#  ['Pasta, cakes, muesli, bread – someone who suffers from celiac disease has to avoid many common foods: the protein gluten, which leads to chronic intestinal inflammation for the sufferers, occurs in most types of grain.',
#   'en',
#   0.9999974627418797],
#  ['The teacher explains the task.', 'en', 0.9999963779877169],
#  ['Note: The work also has masculine zween Theile, zween Zoll, zween Beobachter, feminine zwo oder drey Linien, zwo neue Wahrheiten, neuter zwey Stücke, zwey kleine Glasfenster.',
#   'de',
#   0.9999963840950608],
#  ['Nobody burnt little oil lamps anymore. First they had been replaced by kerosene and gas, then the electricity had come, the brightness of which made each other light look like a meager makeshift.',
#   'en',
#   0.9999967698525514],
#  ['He is singing a beautiful song.', 'en', 0.9999962727078596],
#  ['I am buying one liter of milk.', 'en', 0.9999968193773701],
#  ['A truck delivered fresh goods to the supermarket during the night.',
#   'en',
#   0.9999982692144063],
#  ['polling station', 'en', 0.8571395420021659],
#  ['Alcohol is not a solution to a problem.', 'en', 0.9999959194737658],
#  ['Many flowers bloom in May.', 'en', 0.9999972139939176],
#  ['Man and woman get married, so both possess certain property, even when this is only clothes.',
#   'en',
#   0.9999973252674433],
#  ['The machine is broken.', 'en', 0.9999941592767079],
#  ['I love being by the sea.', 'en', 0.9999983371284804],
#  ['She is a really awesome person.', 'en', 0.9999962510728241],
#  ['The table is two meters long.', 'en', 0.9999986081043439],
#  ['How high is the rent for this apartment?', 'en', 0.9999968107202347],
#  ['A cup of coffee with milk, please.', 'en', 0.9999982109047632],
#  ['One billion is a large number.', 'en', 0.9999948077148613],
#  ['This city has one million inhabitants.', 'en', 0.9999959887751825],
#  ['Please wait five minutes.', 'en', 0.9999975059535301],
#  ['She slept until midday.', 'en', 0.5714268873270918],
#  ['We are meeting in the middle of the square.', 'en', 0.9999983322125119],
#  ['The team meeting is taking place online this Wednesday.',
#   'en',
#   0.9999973449954549],
#  ['At the right moment she took the decisive photo.',
#   'en',
#   0.9999962105052385],
#  ['The working week begins on Monday.', 'en', 0.8571408544585872],
#  ['in the morning', 'en', 0.9999992588323046],
#  ['Keep your mouth shut.', 'en', 0.9999969217551324],
#  ['My mother is calling me.', 'en', 0.9999978139029929],
#  ['The girl laughs loudly.', 'en', 0.999995720005697],
#  ['March is the third month.', 'en', 0.999997471084785],
#  ['She bought new furniture.', 'en', 0.9999960881667584],
#  ['this afternoon', 'en', 0.999997330205073],
#  ['And because he had no reason to conceal his name from her, he introduced himself in all due form.',
#   'en',
#   0.9999952744221768],
#  ['We read the names of the winners out ceremoniously.',
#   'en',
#   0.9999983976844846],
#  ['The north of the country saw the first snow of the year.',
#   'en',
#   0.9999988602319172],
#  ['In November we traditionally place lanterns in the windows.',
#   'en',
#   0.9999967301134629],
#  ['stand-up routine', 'en', 0.9999961231361075],
#  ['Today I only eat fruit.', 'en', 0.99999733804924],
#  ['October has 31 days.', 'en', 0.9999983776062091],
#  ['My grandma bakes the best cake.', 'en', 0.9999955669815845],
#  ['The grandpa is reading to the child.', 'en', 0.9999954483180286],
#  ['Is everything in order in your room?', 'en', 0.9999953713812493],
#  ['on site.', 'fi', 0.999995042193333],
#  ['The sun rises in the East.', 'en', 0.9999960185953436],
#  ['Please bring paper and pens.', 'en', 0.9999957600008524],
#  ['My partner is coming later.', 'en', 0.9999954568925775],
#  ['She is my new partner.', 'en', 0.9999958933414252],
#  ['We are having a party on the weekend.', 'en', 0.9999953291014669],
#  ['Please show your passport.', 'en', 0.9999951123299414],
#  ['We are taking a short break.', 'en', 0.9999951913431087],
#  ['I would like one pound (500g) of cheese.', 'en', 0.7142818396938636],
#  ['I have no idea about that.', 'en', 0.9999983363824737],
#  ['market square', 'sq', 0.9999948889648308],
#  ['The police caught the pickpocket in the act.', 'en', 0.9999974103078519],
#  ['Here’s your mail.', 'fr', 0.7142831641056276],
#  ['Do not forget the postal code.', 'en', 0.9999973989814066],
#  ['I am doing an internship at a company.', 'en', 0.9999971162199959],
#  ['That rarely ever occurs in practice.', 'en', 0.9999964408183523],
#  ['reasonable price.', 'en', 0.9552338912526297],
#  ['The problem arises when we have lots of mails.', 'en', 0.9999955450573054],
#  ['Here is a brochure with information.', 'en', 0.9999966310897758],
#  ['Carbon dioxide contributes by its amount more than any other greenhouse gas to climate change, but its concentration in the air is less than 0.04 percent.',
#   'en',
#   0.999997857217867],
#  ['I am taking an exam next week.', 'en', 0.8571386485861819],
#  ['The apartment is 50 square meters.', 'en', 0.9999963137819395],
#  ['In freefall through space and time\nIn the direction of infinity\nMotes fly in the light\nJust like you and me',
#   'en',
#   0.9999979893292683],
#  ['to foot the bill', 'en', 0.9999976894002078],
#  ['We stay inside when it rains.', 'en', 0.9999978234799727],
#  ['For dinner, there is rice and vegetables.', 'en', 0.9999947293318799],
#  ['The trip was very nice.', 'en', 0.9999963350380867],
#  ['Shall we book the trip at the travel agency?', 'en', 0.9999971074384049],
#  ['The tour guide explains the city to us.', 'en', 0.9999990768731126],
#  ['The repair costs a lot of money.', 'en', 0.9999970200457138],
#  ['excellent restaurant.', 'fr', 0.8605740349531499],
#  ['Please ask at the reception.', 'en', 0.9999984466615974],
#  ['We are taking the S-Bahn (commuter train).', 'en', 0.9999971396151109],
#  ['(meat, etc.) to cook in its own juices', 'en', 0.9999989852625135],
#  ['There is a salad with the main course.', 'en', 0.9999966478057031],
#  ...]

# %%
def build_updated_examples(row: pd.Series) -> List[Dict[str, Any]]:
    examples = list(row.examples)  # shallow copy
    sentence = (row.example_en or "").strip()
    if not sentence:
        return examples

    sentence_lower = sentence.lower()
    target = None
    for entry in examples:
        if not isinstance(entry, dict):
            continue
        existing_sentence = (entry.get("sentence") or "").strip()
        if existing_sentence and existing_sentence.lower() == sentence_lower:
            target = entry
            break

    if target is None:
        target = {"sentence": sentence, "translations": None}
        examples.append(target)

    translations = target.get("translations") or {}
    translations["en"] = sentence
    target["translations"] = translations
    return examples


updates: List[Dict[str, Any]] = []
for _, row in suspected_german.iterrows():
    updated_examples = build_updated_examples(row)
    updates.append(
        {
            "id": int(row.id),
            "lemma": row.lemma,
            "pos": row.pos,
            "example_en": row.example_en,
            "examples": updated_examples,
        }
    )

print(f"Prepared {len(updates)} candidate updates.")
updates[:3]

# %%
APPLY_UPDATES = False  # set to True after manual review

if APPLY_UPDATES:
    with engine.begin() as conn:
        for payload in tqdm(updates, desc="Applying updates"):
            conn.execute(
                text(
                    """
                    UPDATE words
                    SET examples = :examples::jsonb,
                        example_en = NULL,
                        updated_at = NOW()
                    WHERE id = :word_id
                    """
                ),
                {
                    "examples": json.dumps(payload["examples"]),
                    "word_id": payload["id"],
                },
            )
    print("Updates applied. Review the database before exporting snapshots again.")
else:
    print("APPLY_UPDATES is False. Review the `updates` list and toggle the flag when ready.")

# %% [markdown]
# ## Next steps
#
# * Inspect `suspected_german` to confirm detections.
# * Edit the `updates` list manually if you need custom translations or to drop false positives.
# * Set `APPLY_UPDATES = True` and rerun the final cell to write changes back.
# * Re-run `scripts/enrichment/restore-words-from-duplicate.ts` if you need to revert.
# * Once satisfied, export snapshots and upload to Supabase as usual.
